# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
# !pip install -q Pillow

# %%
from PIL import Image
import os

def resize_lossless_tiff(input_image, output_image, scale_factor=0.316):
    image = Image.open(input_image).convert('RGB')
    width, height = image.size
    new_width, new_height = int(width * scale_factor), int(height * scale_factor)
    
    resized_image = image.resize((new_width, new_height), resample=Image.LANCZOS)
    resized_image.save(output_image, compression='tiff_lzw')

# %%
import os
input_directory_0 = "/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Augmented_Dataset/Training/MCL"
output_directory_0 = "/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Final_Dataset/Training/MCL"
if not os.path.exists(output_directory_0):
    os.makedirs(output_directory_0)

for filename in os.listdir(input_directory_0):
    if filename.lower().endswith(('.tif', '.tiff')):
        input_image = os.path.join(input_directory_0, filename)
        output_image = os.path.join(output_directory_0, filename)
        resize_lossless_tiff(input_image, output_image, scale_factor=0.1)

# %%
import os
input_directory_1 = "/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Augmented_Dataset/Training/FL"
output_directory_1 = "/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Final_Dataset/Training/FL"
if not os.path.exists(output_directory_1):
    os.makedirs(output_directory_1)

for filename in os.listdir(input_directory_1):
    if filename.lower().endswith(('.tif', '.tiff')):
        input_image = os.path.join(input_directory_1, filename)
        output_image = os.path.join(output_directory_1, filename)
        resize_lossless_tiff(input_image, output_image, scale_factor=0.1)

# %%
import os
input_directory_2 = "/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Augmented_Dataset/Training/CLL"
output_directory_2 = "/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Final_Dataset/Training/CLL"
if not os.path.exists(output_directory_2):
    os.makedirs(output_directory_2)

for filename in os.listdir(input_directory_2):
    if filename.lower().endswith(('.tif', '.tiff')):
        input_image = os.path.join(input_directory_2, filename)
        output_image = os.path.join(output_directory_2, filename)
        resize_lossless_tiff(input_image, output_image, scale_factor=0.1)

# %%
import os
input_directory_3 = "/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Augmented_Dataset/Testing/MCL"
output_directory_3 = "/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Final_Dataset/Testing/MCL"
if not os.path.exists(output_directory_3):
    os.makedirs(output_directory_3)

for filename in os.listdir(input_directory_3):
    if filename.lower().endswith(('.tif', '.tiff')):
        input_image = os.path.join(input_directory_3, filename)
        output_image = os.path.join(output_directory_3, filename)
        resize_lossless_tiff(input_image, output_image, scale_factor=0.1)

# %%
import os
input_directory_4 = "/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Augmented_Dataset/Testing/FL"
output_directory_4 = "/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Final_Dataset/Testing/FL"
if not os.path.exists(output_directory_4):
    os.makedirs(output_directory_4)

for filename in os.listdir(input_directory_4):
    if filename.lower().endswith(('.tif', '.tiff')):
        input_image = os.path.join(input_directory_4, filename)
        output_image = os.path.join(output_directory_4, filename)
        resize_lossless_tiff(input_image, output_image, scale_factor=0.1)

# %%
import os
input_directory_5 = "/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Augmented_Dataset/Testing/CLL"
output_directory_5 = "/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Final_Dataset/Testing/CLL"
if not os.path.exists(output_directory_5):
    os.makedirs(output_directory_5)

for filename in os.listdir(input_directory_5):
    if filename.lower().endswith(('.tif', '.tiff')):
        input_image = os.path.join(input_directory_5, filename)
        output_image = os.path.join(output_directory_5, filename)
        resize_lossless_tiff(input_image, output_image, scale_factor=0.1)

# %%
import os
input_directory_6 = "/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Augmented_Dataset/Validation/MCL"
output_directory_6 = "/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Final_Dataset/Validation/MCL"
if not os.path.exists(output_directory_6):
    os.makedirs(output_directory_6)

for filename in os.listdir(input_directory_6):
    if filename.lower().endswith(('.tif', '.tiff')):
        input_image = os.path.join(input_directory_6, filename)
        output_image = os.path.join(output_directory_6, filename)
        resize_lossless_tiff(input_image, output_image, scale_factor=0.1)

# %%
import os
input_directory_7 = "/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Augmented_Dataset/Validation/FL"
output_directory_7 = "/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Final_Dataset/Validation/FL"
if not os.path.exists(output_directory_7):
    os.makedirs(output_directory_7)

for filename in os.listdir(input_directory_7):
    if filename.lower().endswith(('.tif', '.tiff')):
        input_image = os.path.join(input_directory_7, filename)
        output_image = os.path.join(output_directory_7, filename)
        resize_lossless_tiff(input_image, output_image, scale_factor=0.1)

# %%
import os
input_directory_8 = "/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Augmented_Dataset/Validation/CLL"
output_directory_8 = "/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Final_Dataset/Validation/CLL"
if not os.path.exists(output_directory_8):
    os.makedirs(output_directory_8)

for filename in os.listdir(input_directory_8):
    if filename.lower().endswith(('.tif', '.tiff')):
        input_image = os.path.join(input_directory_8, filename)
        output_image = os.path.join(output_directory_8, filename)
        resize_lossless_tiff(input_image, output_image, scale_factor=0.1)

# %%
print(len(os.listdir("/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Final_Dataset/Validation/CLL")))
# Out:
# 926

# %%
print(len(os.listdir("/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Final_Dataset/Validation/FL")))
# Out:
# 932

# %%
print(len(os.listdir("/content/drive/MyDrive/AI - Sem 6/Malignant Lymphoma Classification/Dataset/Final_Dataset/Validation/MCL")))
# Out:
# 926
